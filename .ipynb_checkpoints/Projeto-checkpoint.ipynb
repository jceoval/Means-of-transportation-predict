# %% [markdown]
# # Mineração Estatística de Dados:
# # Projeto 1: Pré-processamento de dados e classificação

# %% [markdown]
# ### Alunos
# - Alexandre Batistellas Bellas&emsp;&emsp;&emsp;&nbsp;&emsp;9763168
# - Juan Carlos Elias Obando Valdivia&emsp;&nbsp;7487156

# %% [markdown]
# ## 1 – Considere a base de dados (arquivo dataset_5secondWindow%5B1%5D.csv):
# ## https://www.kaggle.com/fschwartzer/tmd-dataset-5-seconds-sliding-window

# %% [markdown]
# ## 2 – Realize o pré-processamento dos dados: Verifque se há NaN ou outros erros no dados. Selecione apenas os atributos relevantes e numéricos.

# %% [markdown]
# ### Leitura e pré-processamento dos dados

# %% [markdown]
# Vamos ler o conjunto de dados:

# %%
import random
random.seed(1)
# Pandas is used for data manipulation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#CSV file
features = pd.read_csv("data/dataset_5secondWindow%5B1%5D.csv", header=(0))
print(features.shape)
features.head(10)
# Out:
# (5893, 14)
#     time  android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0   78.0                           9.811476                          9.758895
# 1  145.0                           9.939207                          7.707437
# 2  150.0                           9.827178                          9.804817
# 3  105.0                           9.673039                          7.659674
# 4   77.0                           9.993466                          8.965621
# 5  559.0                           9.330482                          9.149029
# 6   41.0                           9.789771                          9.758751
# 7   20.0                           9.906011                          6.431646
# 8   35.0                           9.639711                          8.996134
# 9   27.0                           9.602109                          9.014786
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                          9.849411                          0.014626
# 1                         17.146631                          1.775944
# 2                          9.849262                          0.011199
# 3                         12.304298                          0.862553
# 4                         10.891645                          0.504117
# 5                          9.520044                          0.103857
# 6                          9.816197                          0.013489
# 7                         14.202603                          1.044684
# 8                         10.027802                          0.255053
# 9                         10.068528                          0.267791
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope#min  \
# 0                       0.001651                      0.000000
# 1                       0.036326                      0.011669
# 2                       0.001525                      0.000000
# 3                       0.036440                      0.020463
# 4                       0.183202                      0.020667
# 5                       0.000000                      0.000000
# 6                       0.004100                      0.002732
# 7                       0.140902                      0.006567
# 8                       0.041554                      0.008014
# 9                       0.037451                      0.007174
#
#    android.sensor.gyroscope#max  android.sensor.gyroscope#std  sound#mean  \
# 0                      0.003533                      0.000737    0.000000
# 1                      0.059388                      0.020290   89.200210
# 2                      0.002609                      0.000713    0.000000
# 3                      0.052512                      0.010553   87.470377
# 4                      0.380875                      0.098819   89.770732
# 5                      0.000000                      0.000000   57.361127
# 6                      0.006579                      0.001801   65.158369
# 7                      0.690414                      0.119667    0.000000
# 8                      0.123026                      0.030074   89.808441
# 9                      0.084820                      0.021391   89.815738
#
#    sound#min  sound#max  sound#std target
# 0   0.000000   0.000000   0.000000  Still
# 1  89.065143  89.335277   0.191013    Car
# 2   0.000000   0.000000   0.000000  Still
# 3  87.470377  87.470377   2.284186    Car
# 4  89.770732  89.770732   0.006389    Car
# 5  57.361127  57.361127   1.006611    Car
# 6  65.158369  65.158369   0.000000  Train
# 7   0.000000   0.000000   0.000000    Bus
# 8  89.808441  89.808441   0.010171    Bus
# 9  89.815738  89.815738   0.004995  Train

# %% [markdown]
# Primeiramente, vamos remover os "NaN" do arquivo, apagando as linhas que contém esse problema:

# %%
features = features.dropna()
print(features.shape)
# Out:
# (5893, 14)

# %% [markdown]
# Vamos remover as linhas duplicadas:

# %%
features.duplicated()
features = features.drop_duplicates()
print(features.shape)
# Out:
# (5893, 14)

# %% [markdown]
# Vamos remover as linhas com "?" ou qualquer outro caracter que indique um erro ou entrada faltante.
# Primeiramente, convertemos essas entradas para "NaN":

# %%
features = features.replace('?', np.nan)
features = features.dropna()
print(features.shape)
# Out:
# (5893, 14)

# %% [markdown]
# Obtendo as classes e os atributos do dataset:

# %%
classes = pd.unique(features[features.columns[-1]]) #name of the classes
classes = np.array(classes, dtype=str) #convert on array
print("Classes únicas no conjunto de dados:", classes)
list_labels = list(features.columns)
print("\nNomes dos atributos e classe:",list_labels)
# Out:
# Classes únicas no conjunto de dados: ['Still' 'Car' 'Train' 'Bus' 'Walking']
#
# Nomes dos atributos e classe: ['time', 'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std', 'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min', 'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std', 'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'target']

# %% [markdown]
# Vamos construir as variáveis $X$ e $Y$, sendo que o processo classificação se resume em estimar a função $f$ na relação $Y=f(X)+\epsilon$, onde $\epsilon$ é o erro, que tem distribuição normal com média igual a zero e variância $\sigma^2$.

# %%
#Variável Y => classes de base para a classificação
Y = np.array(features[list_labels[-1]], dtype=str)

#Removendo os labels do features
features = features.drop(list_labels[-1], axis = 1)
#Tirando o atributo "time"
features = features.drop(list_labels[0], axis = 1)

#Variável X => convertendo o features para numpy array
X = np.array(features)

features.head(10)
# Out:
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
# 5                           9.330482                          9.149029
# 6                           9.789771                          9.758751
# 7                           9.906011                          6.431646
# 8                           9.639711                          8.996134
# 9                           9.602109                          9.014786
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                          9.849411                          0.014626
# 1                         17.146631                          1.775944
# 2                          9.849262                          0.011199
# 3                         12.304298                          0.862553
# 4                         10.891645                          0.504117
# 5                          9.520044                          0.103857
# 6                          9.816197                          0.013489
# 7                         14.202603                          1.044684
# 8                         10.027802                          0.255053
# 9                         10.068528                          0.267791
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope#min  \
# 0                       0.001651                      0.000000
# 1                       0.036326                      0.011669
# 2                       0.001525                      0.000000
# 3                       0.036440                      0.020463
# 4                       0.183202                      0.020667
# 5                       0.000000                      0.000000
# 6                       0.004100                      0.002732
# 7                       0.140902                      0.006567
# 8                       0.041554                      0.008014
# 9                       0.037451                      0.007174
#
#    android.sensor.gyroscope#max  android.sensor.gyroscope#std  sound#mean  \
# 0                      0.003533                      0.000737    0.000000
# 1                      0.059388                      0.020290   89.200210
# 2                      0.002609                      0.000713    0.000000
# 3                      0.052512                      0.010553   87.470377
# 4                      0.380875                      0.098819   89.770732
# 5                      0.000000                      0.000000   57.361127
# 6                      0.006579                      0.001801   65.158369
# 7                      0.690414                      0.119667    0.000000
# 8                      0.123026                      0.030074   89.808441
# 9                      0.084820                      0.021391   89.815738
#
#    sound#min  sound#max  sound#std
# 0   0.000000   0.000000   0.000000
# 1  89.065143  89.335277   0.191013
# 2   0.000000   0.000000   0.000000
# 3  87.470377  87.470377   2.284186
# 4  89.770732  89.770732   0.006389
# 5  57.361127  57.361127   1.006611
# 6  65.158369  65.158369   0.000000
# 7   0.000000   0.000000   0.000000
# 8  89.808441  89.808441   0.010171
# 9  89.815738  89.815738   0.004995

# %% [markdown]
# Verificando o balanceamento das classes:

# %%
cl = np.unique(Y)
ncl = np.zeros(len(cl))
for i in np.arange(0, len(cl)):
    a = Y == cl[i]
    ncl[i] = len(Y[a])
print(cl)
print(ncl)
# Out:
# ['Bus' 'Car' 'Still' 'Train' 'Walking']
# [1178. 1180. 1179. 1179. 1177.]

# %%
numbers = np.arange(0, len(cl))
plt.bar(numbers, ncl, alpha=.45, color=['red', 'green', 'blue', 'orange', 'cyan'])
plt.xticks(numbers, cl)
plt.title('Número de elementos em cada classe')
plt.show(True)

# %%
#Saving feature names for later use
feature_list = list(features.columns)
print(feature_list)
# Out:
# ['android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min', 'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std', 'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min', 'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std', 'sound#mean', 'sound#min', 'sound#max', 'sound#std']

# %% [markdown]
# As classes estão balanceadas, o que nos dá uma melhor análise sobre os dados.

# %% [markdown]
# ### Conjuntos de teste e treinamento

# %% [markdown]
# Para treinar o classificador, precisamos definir o conjunto de teste e treinamento.

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
p = 0.7
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 1-p, random_state = 42)

# %% [markdown]
# A partir desses dados, podemos realizar o processo de classificação.

# %% [markdown]
# ## 3 - No caso do classificador Knn, verifique o efeito do parâmetro k na classificação.

# %% [markdown]
# ### k-vizinhos
#
# Podemos realizar a classificação usando a biblioteca scikit-learn (https://scikit-learn.org). As métricas possíveis podem ser vistas em: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.DistanceMetric.html

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

vscore = []
vk = []
for k in np.arange(1, 15):
    model = KNeighborsClassifier(n_neighbors=k)
    # Train the model using the training sets
    model.fit(train_x,train_y)
    #Predict Output
    pred_y = model.predict(test_x)
    score = accuracy_score(pred_y, test_y)
    vscore.append(score)
    vk.append(k)
plt.figure(figsize=(15,10))
plt.plot(vk, vscore, marker='s', linestyle='-', color="blue", linewidth=2.5)
plt.xlabel("k", fontsize=20)
plt.ylabel("Acurácia", fontsize=20)
plt.grid(True)
plt.show(True)

# %% [markdown]
# Há certa instabilidade na acurácia com o crescimento de k até o valor do parâmetro chegar a 6. A partir desse valor, há um claro decréscimo no valor da acurácia com o crescimento do valor de k. Pelo gráfico plotado acima, vemos que para k = 1 o algoritmo obteve melhor acurácia.

# %%
#Registrando o valor da acurácia do KNN para k = 0
score_knn = vscore[0]

# %% [markdown]
# ## 4 – Compare	os	classificadores:
# - ### knn (melhor	k	observado	no	item	anterior)
# - ### Decisão	Bayesiana
# - ### Naive	Bayes

# %% [markdown]
# ### Classificador Bayesiano

# %% [markdown]
# Vamos considerar o caso paramétrico, assumindo que cada variável está distribuída de acordo com uma distribuição normal.
#
# Já selecionamos os conjuntos de treinamento e teste. No conjunto de treinamento, vamos calcular a média e desvio padrão de cada atributo para cada classe. A seguir, reaizamos a classificação, dos dados usando a teoria da decisão Bayesiana, isto é: $X\in i$ se, e somente se, $P(C_{i}|X)=maxP(C_{j}|X)$ para todo $j$.

# %%
from scipy.stats import multivariate_normal
#matrix to store the probabilities
P = pd.DataFrame(data=np.zeros((train_x.shape[0], len(classes))), columns= classes)

# %%
for i in np.arange(0, len(classes)):
    #elements tem todos os identificadores dos exemplos do conjunto de treinamento cujo rótulo é classe[i] 
    elements = tuple(np.where(train_y == classes[i]))
    #Z contém todos os exemplos do conjunto de treinamento cujo rótulo é classe[i]
    Z = train_x[elements,:][0]
    #calcula a média por coluna(axis = 0)
    m = np.mean(Z, axis = 0)
    #calcula a covariancia da transposta de Z
    cv = np.cov(np.transpose(Z))
    #para cada exemplo do conjunto de teste
    for j in np.arange(0, test_x.shape[0]):
        #pega cada exemplo do conjunto de teste(todos os atributos)
        x = test_x[j,:]
        # probability density function for multivariate_normal is
        #f(x) = \frac{1}{\sqrt{(2 \pi)^k \det \Sigma}} \exp\left( -\frac{1}{2} (x - \mu)^T \Sigma^{-1} (x - \mu) \right),
        pj = multivariate_normal.pdf(x, mean=m, cov=cv)
        P[classes[i]][j] = pj

# %%
pred_y = []
#np.array(test_x.shape[0], dtype=str)
#para cada exemplo do conjunto de teste 
for i in np.arange(0, test_x.shape[0]):
    #pegar o identificador da coluna com maior probabilidade de cada exemplo
    c = np.argmax(np.array(P.iloc[[i]]))
    pred_y.append(classes[c])
pred_y = np.array(pred_y, dtype=str)

# %%
from sklearn.metrics import accuracy_score
score_bayes = accuracy_score(pred_y, test_y)

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# Vamos considerar a biblioteca scikit-learn.

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(train_x, train_y)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pred_y = gnb.predict(test_x)
score_GNB = accuracy_score(pred_y, test_y)

# %% [markdown]
# A matriz de confusão:

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(test_y, pred_y))
# Out:
# [[ 69  73  29 123  14]
#  [ 21 118  39 164  14]
#  [  7   6 191 165  11]
#  [  8  14  38 275   6]
#  [ 26  18   6  29 304]]

# %% [markdown]
# ### Comparação entre os classificadores

# %%
print("Acurácias:\n")
print("\tKNN para k = 1: \t%.4f" % score_knn)
print("\tDecisão Bayesiana: \t%.4f" % score_bayes)
print("\tNaive Bayes: \t\t%.4f"% score_GNB)

acur_aux = [vscore[0], score_bayes, score_GNB]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['KNN (k = 1)', 'Classif. Bayesiano', 'Naive Bayes']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para os classificadores')
plt.show(True)
# Out:
# Acurácias:
#
# 	KNN para k = 1: 	0.7460
# 	Decisão Bayesiana: 	0.5950
# 	Naive Bayes: 		0.5413

# %% [markdown]
# É possível concluir que o algoritmo KNN, para k = 1, teve maior acurácia entre os algoritmos analisados.

# %% [markdown]
# ## 5 – Verifique	o	efeito	da	normalização	(atributos	em	[0,1])	e	padronização (atributos	com	média	0	e	variância	1)	dos	dados.	Compare	os	casos	sem	processamento,	com	padronização	e	com	normalização	para	os	classificadores:
# - ### knn	(melhor	k	observado	no	item	anterior)
# - ### Decisão	Bayesiana
# - ### Naive	Bayes

# %%
#Bibliotecas para normalização e padronização
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### KNN

# %%
def acuraciaKnnValor(features, tipo=0, p=0.7, metric='euclidean', k=1, dist=2): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    
    X = np.array(features, dtype=float)
    #se quisermos a acurácia com padronização 
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização"
        
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    
    model = KNeighborsClassifier(n_neighbors=k, p=dist, metric=metric)
    # Train the model using the training sets
    model.fit(train_x,train_y)
    #Predict Output
    pred_y = model.predict(test_x) 
    score = accuracy_score(pred_y, test_y)
    return score

knn_sem_pros = acuraciaKnnValor(features, tipo=0)
knn_com_padr = acuraciaKnnValor(features, tipo=1)
knn_com_norm = acuraciaKnnValor(features, tipo=2)

print('Acurácia sem processamento:\t', knn_sem_pros)
print('Acurácia com padronização:\t', knn_com_padr)
print('Acurácia com normalização:\t', knn_com_norm)

acur_aux = [knn_sem_pros, knn_com_padr, knn_com_norm]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['sem processamento', 'com padronização', 'com normalização']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para o KNN(k=1)')
plt.show(True)
# Out:
# Acurácia sem processamento:	 0.7460407239819005
# Acurácia com padronização:	 0.793552036199095
# Acurácia com normalização:	 0.7743212669683258

# %% [markdown]
# A padronização teve como resultado maior acurácia no algoritmo KNN.

# %% [markdown]
# ### Classificador Bayesiano

# %%
def acuraciaBayesValor(features, tipo=0, p=0.7): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    X = np.array(features, dtype=float)
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização"
    
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    P = pd.DataFrame(data=np.zeros((test_x.shape[0], len(classes))), columns = classes)
    for i in np.arange(0, len(classes)):
        elements = tuple(np.where(train_y == classes[i]))
        Z = train_x[elements,:][0]
        m = np.mean(Z, axis = 0)
        cv = np.cov(np.transpose(Z))
        for j in np.arange(0,test_x.shape[0]):
            x = test_x[j,:]
            pj = multivariate_normal.pdf(x, mean=m, cov=cv)
            P[classes[i]][j] = pj
    
    pred_y = []
    for i in np.arange(0, test_x.shape[0]):
        c = np.argmax(np.array(P.iloc[[i]]))
        pred_y.append(classes[c])
    pred_y = np.array(pred_y, dtype=str)
    
    score = accuracy_score(pred_y, test_y)
    return score

class_sem_pros = acuraciaBayesValor(features, tipo=0)
class_com_padr = acuraciaBayesValor(features, tipo=1)
class_com_norm = acuraciaBayesValor(features, tipo=2)

print('Acurácia sem processamento:\t', class_sem_pros)
print('Acurácia com padronização:\t', class_com_padr)
print('Acurácia com normalização:\t', class_com_norm)

acur_aux = [class_sem_pros, class_com_padr, class_com_norm]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['sem processamento', 'com padronização', 'com normalização']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para o classificador bayesiano')
plt.show(True)
# Out:
# Acurácia sem processamento:	 0.5950226244343891
# Acurácia com padronização:	 0.5950226244343891
# Acurácia com normalização:	 0.5950226244343891

# %% [markdown]
# Independente do tipo de processamento de dados, a acurácia do Classificador Bayesiano manteve-se estável.

# %% [markdown]
# ### Naive Bayes

# %%
def acuraciaNaiveBayesValor(features, tipo=0, p=0.7): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    
    X = np.array(features, dtype=float)
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização" 
    
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    gnb = GaussianNB()
    gnb.fit(train_x, train_y)
    
    pred_y = gnb.predict(test_x)
    score = accuracy_score(pred_y, test_y)
    return score

naive_sem_pros = acuraciaNaiveBayesValor(features, tipo=0)
naive_com_padr = acuraciaNaiveBayesValor(features, tipo=1)
naive_com_norm = acuraciaNaiveBayesValor(features, tipo=2)

print('Acurácia sem processamento:\t', naive_sem_pros)
print('Acurácia com padronização:\t', naive_com_padr)
print('Acurácia com normalização:\t', naive_com_norm)

acur_aux = [naive_sem_pros, naive_com_padr, naive_com_norm]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['sem processamento', 'com padronização', 'com normalização']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para o Naive Bayes')
plt.show(True)
# Out:
# Acurácia sem processamento:	 0.541289592760181
# Acurácia com padronização:	 0.541289592760181
# Acurácia com normalização:	 0.541289592760181

# %% [markdown]
# Assim como no classificador Bayesiano, independente do tipo de processamento, a acurácia para o classificador Naive Bayes manteve-se estável.

# %% [markdown]
# ## 6 – Mostre a matriz de correlação entre os atributos. Considere os atributos com menor correlação (por exemplo, menor do que 0.5). Realize a classificação novamente apenas com esses atributos. A acurácia melhora?

# %% [markdown]
# A matriz de correlação entre as variáveis:

# %%
import seaborn as sns

#Obtendo a matriz de correlação
corr = features.corr()

#Apresentando num heatmap
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True)

# %% [markdown]
# Apresentando as variáveis correlacionadas:

# %%
p = 0.5
var = []
for i in corr.columns:
    for j in corr.columns:
        if(i != j):
            if np.abs(corr[i][j]) < p:
                var.append([i, j])

print('Variáveis com correlação menor que 0.5:\n')
for v in var:
    print(v)
# Out:
# Variáveis com correlação menor que 0.5:
#
# ['android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min']
# ['android.sensor.accelerometer#mean', 'android.sensor.gyroscope#min']
# ['android.sensor.accelerometer#mean', 'android.sensor.gyroscope#std']
# ['android.sensor.accelerometer#mean', 'sound#mean']
# ['android.sensor.accelerometer#mean', 'sound#min']
# ['android.sensor.accelerometer#mean', 'sound#max']
# ['android.sensor.accelerometer#mean', 'sound#std']
# ['android.sensor.accelerometer#min', 'android.sensor.accelerometer#mean']
# ['android.sensor.accelerometer#min', 'sound#mean']
# ['android.sensor.accelerometer#min', 'sound#min']
# ['android.sensor.accelerometer#min', 'sound#max']
# ['android.sensor.accelerometer#min', 'sound#std']
# ['android.sensor.accelerometer#max', 'sound#mean']
# ['android.sensor.accelerometer#max', 'sound#min']
# ['android.sensor.accelerometer#max', 'sound#max']
# ['android.sensor.accelerometer#max', 'sound#std']
# ['android.sensor.accelerometer#std', 'sound#mean']
# ['android.sensor.accelerometer#std', 'sound#min']
# ['android.sensor.accelerometer#std', 'sound#max']
# ['android.sensor.accelerometer#std', 'sound#std']
# ['android.sensor.gyroscope#mean', 'sound#mean']
# ['android.sensor.gyroscope#mean', 'sound#min']
# ['android.sensor.gyroscope#mean', 'sound#max']
# ['android.sensor.gyroscope#mean', 'sound#std']
# ['android.sensor.gyroscope#min', 'android.sensor.accelerometer#mean']
# ['android.sensor.gyroscope#min', 'sound#mean']
# ['android.sensor.gyroscope#min', 'sound#min']
# ['android.sensor.gyroscope#min', 'sound#max']
# ['android.sensor.gyroscope#min', 'sound#std']
# ['android.sensor.gyroscope#max', 'sound#mean']
# ['android.sensor.gyroscope#max', 'sound#min']
# ['android.sensor.gyroscope#max', 'sound#max']
# ['android.sensor.gyroscope#max', 'sound#std']
# ['android.sensor.gyroscope#std', 'android.sensor.accelerometer#mean']
# ['android.sensor.gyroscope#std', 'sound#mean']
# ['android.sensor.gyroscope#std', 'sound#min']
# ['android.sensor.gyroscope#std', 'sound#max']
# ['android.sensor.gyroscope#std', 'sound#std']
# ['sound#mean', 'android.sensor.accelerometer#mean']
# ['sound#mean', 'android.sensor.accelerometer#min']
# ['sound#mean', 'android.sensor.accelerometer#max']
# ['sound#mean', 'android.sensor.accelerometer#std']
# ['sound#mean', 'android.sensor.gyroscope#mean']
# ['sound#mean', 'android.sensor.gyroscope#min']
# ['sound#mean', 'android.sensor.gyroscope#max']
# ['sound#mean', 'android.sensor.gyroscope#std']
# ['sound#mean', 'sound#std']
# ['sound#min', 'android.sensor.accelerometer#mean']
# ['sound#min', 'android.sensor.accelerometer#min']
# ['sound#min', 'android.sensor.accelerometer#max']
# ['sound#min', 'android.sensor.accelerometer#std']
# ['sound#min', 'android.sensor.gyroscope#mean']
# ['sound#min', 'android.sensor.gyroscope#min']
# ['sound#min', 'android.sensor.gyroscope#max']
# ['sound#min', 'android.sensor.gyroscope#std']
# ['sound#min', 'sound#std']
# ['sound#max', 'android.sensor.accelerometer#mean']
# ['sound#max', 'android.sensor.accelerometer#min']
# ['sound#max', 'android.sensor.accelerometer#max']
# ['sound#max', 'android.sensor.accelerometer#std']
# ['sound#max', 'android.sensor.gyroscope#mean']
# ['sound#max', 'android.sensor.gyroscope#min']
# ['sound#max', 'android.sensor.gyroscope#max']
# ['sound#max', 'android.sensor.gyroscope#std']
# ['sound#max', 'sound#std']
# ['sound#std', 'android.sensor.accelerometer#mean']
# ['sound#std', 'android.sensor.accelerometer#min']
# ['sound#std', 'android.sensor.accelerometer#max']
# ['sound#std', 'android.sensor.accelerometer#std']
# ['sound#std', 'android.sensor.gyroscope#mean']
# ['sound#std', 'android.sensor.gyroscope#min']
# ['sound#std', 'android.sensor.gyroscope#max']
# ['sound#std', 'android.sensor.gyroscope#std']
# ['sound#std', 'sound#mean']
# ['sound#std', 'sound#min']
# ['sound#std', 'sound#max']

# %% [markdown]
# Analisando o heatmap plotado, podemos ver que existem dois grandes blocos de atributos que se correlacionam. Assim, devemos escolher um subconjunto de cada bloco de forma que os atributos desses subconjuntos tenham menor correlação com os outros atributos.
#
# Analisando os pares de variáveis apresentados acima, vemos que os atributos de média e desvio padrão (*mean* e *std*) possuem menor correlação, além de que os valores *max* e *min* se tornam redundantes após se ter os valores da média e do desvio padrão.
#
# Ou seja, as variáveis *android.sensor.accelerometer#mean*, *android.sensor.accelerometer#std*, *android.sensor.gyroscope#mean*, *android.sensor.gyroscope#std*, *sound#mean* e *sound#std* foram escolhidas.
#
# Realizando novamente a classificação:

# %%
#Atrbutos relevantes para a análise
atrib = ['android.sensor.accelerometer#mean',
         'android.sensor.accelerometer#std',
         'android.sensor.gyroscope#mean',
         'android.sensor.gyroscope#std',
         'sound#mean',
         'sound#std']

#Filtrando atributos
features_corr = features.filter(atrib)
features_corr.head()
# Out:
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#std  \
# 0                           9.811476                          0.014626
# 1                           9.939207                          1.775944
# 2                           9.827178                          0.011199
# 3                           9.673039                          0.862553
# 4                           9.993466                          0.504117
#
#    android.sensor.gyroscope#mean  android.sensor.gyroscope#std  sound#mean  \
# 0                       0.001651                      0.000737    0.000000
# 1                       0.036326                      0.020290   89.200210
# 2                       0.001525                      0.000713    0.000000
# 3                       0.036440                      0.010553   87.470377
# 4                       0.183202                      0.098819   89.770732
#
#    sound#std
# 0   0.000000
# 1   0.191013
# 2   0.000000
# 3   2.284186
# 4   0.006389

# %%
#Classificando sem processamento
acur_knn_corr = acuraciaKnnValor(features_corr, tipo=0)
acur_class_corr = acuraciaBayesValor(features_corr, tipo=0)
acur_naive_corr = acuraciaNaiveBayesValor(features, tipo=0)

#Printando e comparando
print("==== Acurácias para todas as variáveis ====")
print("\tKNN para k = 1: \t\t%.4f" % score_knn)
print("\tDecisão Bayesiana: \t\t%.4f" % score_bayes)
print("\tNaive Bayes: \t\t\t%.4f\n"% score_GNB)

print("==== Acurácias para as variáveis selecionadas ====")
print("\tKNN para k = 1: \t\t%.4f" % acur_knn_corr)
print("\tDecisão Bayesiana: \t\t%.4f" % acur_class_corr)
print("\tNaive Bayes: \t\t\t%.4f"% acur_naive_corr)
# Out:
# ==== Acurácias para todas as variáveis ====
# 	KNN para k = 1: 		0.7460
# 	Decisão Bayesiana: 		0.5950
# 	Naive Bayes: 			0.5413
#
# ==== Acurácias para as variáveis selecionadas ====
# 	KNN para k = 1: 		0.7783
# 	Decisão Bayesiana: 		0.6126
# 	Naive Bayes: 			0.5413

# %% [markdown]
# Diante da comparação das acurácias, podemos concluir que escolhendo as variáveis com menor correlação (considerando abaixo de 0.5) aumenta a acurácia para os algoritmos KNN e Classificador Bayesiano. No entanto, para o Naive Bayes, a acurácia se mantém estável.

# %% [markdown]
# ## 7	– Verifique	qual	dos	classificadores	é	mais	robusto	com	relação	à	presença	de ruídos.	Para	isso:
# - ### Aplique	a	normalização	dos	dados	para	que	os	atributos	apresentem	média	igual	a	zero	e	variância	igual	a	1.
# - ### Inclua	em	X%	dos	atributos,	um	valor	normalmente	distribuído	com	média	zero	e	variância	1.	Considere	toda	a	matriz	dos	dados,	sorteando uma	posição	da	matriz	de	forma	aleatória.
# - ### Varie	o	nível	de	ruído,	de	0	a	50%	(em	passos	de	5%)	e	avalie	como	muda	a	classificação.	Construa	um	gráfico	de	X% de	ruído versus	porcentagem	de	classificação	correta.	Coloque	a	média	e	o	desvio	padrão	calculados	a	partir	de	ao	menos	10	simulações.	Considere	70%	dos	dados	no	conjunto	de	treinamento.
# - ### Discuta os	resultados.

# %%
def insereRuidoEmCadaClassificador(X, num_pos, tipo=0):
    acur_knn = []
    acur_bayesiano = []
    acur_naive_bayes = []

    #Definindo o X% -> indo de 0 a 50%
    for porcentagemX in np.arange(0, 51, 5):

        #print("Porcentagem dos dados a serem substituídos:", porcentagemX)
        num_sorted_pos = int(np.around(num_pos * porcentagemX / 100))
        #print("Número de posições a serem escolhidas:\n", num_sorted_pos, end='\n\n')

        #Set que guardará as x% posições randômicas da matriz
        posicoes = set()

        #Escolha aleatória das posições da matriz e inserindo no set
        while len(posicoes) != num_sorted_pos:
            num_rand_i = np.random.randint(0, np.shape(X)[0])
            num_rand_j = np.random.randint(0, np.shape(X)[1])
            num_rand = tuple([num_rand_i, num_rand_j])
            #print(num_rand)
            posicoes.add(num_rand)

        #Geração do conjunto de dados normalmente distribuído
        num_normal = np.random.normal(0, 1, num_sorted_pos)

        #Inserção do conjunto de dados normalmente distribuído no conjunto original
        for num, pos in zip(num_normal, posicoes):
            X[pos[0]][pos[1]] = num

        acur_knn.append(100*acuraciaKnnValor(X, tipo=tipo))
        acur_bayesiano.append(100*acuraciaBayesValor(X, tipo=tipo))
        acur_naive_bayes.append(100*acuraciaNaiveBayesValor(X, tipo=tipo))
    
    return acur_knn, acur_bayesiano, acur_naive_bayes

# %%
#Obtendo o número de posições da matriz
num_pos = np.shape(X)[0] * np.shape(X)[1]
print("Tamanho da matriz:\n", np.shape(X), end='\n\n')
print("Número de posições na matriz:\n", num_pos, end='\n\n')
# Out:
# Tamanho da matriz:
#  (5893, 12)
#
# Número de posições na matriz:
#  70716

# %%
#Atenção: essa célula demora cerca de 3 minutos para concluir
num_simulacoes = 10

#Obtendo as diferentes simulações
plot_porcentagens = []
sim_knn = []
sim_bayesiano = []
sim_naive_bayes = []

for i in range(11):
    plot_porcentagens.append(i*5)

#Inserindo nas listas acima para posterior análise
for i in range(num_simulacoes):
    X_aux = np.copy(X)
    
    ak, acb, anb = insereRuidoEmCadaClassificador(X_aux, num_pos, tipo=2)
    sim_knn.append(ak)
    sim_bayesiano.append(acb)
    sim_naive_bayes.append(anb)

# %%
#Configurando matplotlib
fig = plt.figure(figsize=(15,10))

#Obtendo médias e desvios padrão
mean_knn = np.mean(sim_knn, axis=0)
mean_bayesiano = np.mean(sim_bayesiano, axis=0)
mean_naive_bayes = np.mean(sim_naive_bayes, axis=0)

std_knn = np.std(sim_knn, axis=0)
std_bayesiano = np.std(sim_bayesiano, axis=0)
std_naive_bayes = np.std(sim_naive_bayes, axis=0)

#Plotar o gráfico das 3 classificações com média e respectivo erro
plt.xlabel('Porcentagem dos dados de ruído')
plt.ylabel('Porcentagem de acurácia')
plt.grid(True)

#Plot da linha com seus respectivos erros (apesar de não serem expressivos)
plt.errorbar(plot_porcentagens, mean_knn, std_knn, label='KNN para k = 1', marker='o')
plt.errorbar(plot_porcentagens, mean_bayesiano, std_bayesiano, label='Classificador Bayesiano', marker='o')
plt.errorbar(plot_porcentagens, mean_naive_bayes, std_naive_bayes, label='Naive Bayes', marker='o')

plt.legend(loc='best')

plt.show(True)

# %%
#Média e desvio padrão para cada classificador
print("==== Cálculo de médias e desvio padrão da acurácia para cada classificador ====\n")

#KNN
print("\t\t\tMédia (%)\tDesvio padrão (%)\tPorcentagem de ruído")
print("KNN com k = 1", end='')
for mean, std, porc in zip(mean_knn, std_knn, plot_porcentagens):
      print("\t\t%.4f\t\t%.4f\t\t\t%s\n\t" % (mean, std, porc), end='')
print("\nMédia\t\t\t%.4f\t\t%.4f" % (np.mean(mean_knn), np.mean(std_knn)))
        
#Classificador Bayesiano
print('\n')
print("\t\t\tMédia (%)\tDesvio padrão (%)\tPorcentagem de ruído")    
print("Classif. Bayesiano\t", end='')
for mean, std, porc in zip(mean_bayesiano, std_bayesiano, plot_porcentagens):
      print("%.4f\t\t%.4f\t\t\t%s\n\t\t\t" % (mean, std, porc), end='')
print("\nMédia\t\t\t%.4f\t\t%.4f" % (np.mean(mean_bayesiano), np.mean(std_bayesiano)))
        
#Naive Bayes
print('\n')
print("\t\t\tMédia (%)\tDesvio padrão (%)\tPorcentagem de ruído")       
print("Naive Bayes\t\t", end='')
for mean, std, porc in zip(mean_naive_bayes, std_naive_bayes, plot_porcentagens):
      print("%.4f\t\t%.4f\t\t\t%s\n\t\t\t" % (mean, std, porc), end='')
print("\nMédia\t\t\t%.4f\t\t%.4f" % (np.mean(mean_naive_bayes), np.mean(std_naive_bayes)))
# Out:
# ==== Cálculo de médias e desvio padrão da acurácia para cada classificador ====
#
# 			Média (%)	Desvio padrão (%)	Porcentagem de ruído
# KNN com k = 1		77.4321		0.0000			0
# 			65.6561		0.6122			5
# 			53.6765		0.9290			10
# 			44.4174		0.9946			15
# 			38.0260		0.8150			20
# 			32.7941		0.8465			25
# 			29.9491		1.0479			30
# 			26.1821		0.9097			35
# 			23.9310		1.1451			40
# 			21.7364		1.0007			45
# 			21.2443		0.5618			50
#
# Média			39.5496		0.8057
#
#
# 			Média (%)	Desvio padrão (%)	Porcentagem de ruído
# Classif. Bayesiano	59.5023		0.0000			0
# 			51.7873		1.1375			5
# 			49.8303		0.8293			10
# 			46.4536		0.8138			15
# 			41.6686		0.9599			20
# 			37.2738		1.1918			25
# 			33.2014		0.9458			30
# 			28.8462		1.1008			35
# 			24.9434		0.8733			40
# 			23.0656		0.6473			45
# 			21.9231		0.6974			50
#
# Média			38.0450		0.8361
#
#
# 			Média (%)	Desvio padrão (%)	Porcentagem de ruído
# Naive Bayes		54.1290		0.0000			0
# 			49.5814		0.8466			5
# 			49.6097		0.9547			10
# 			47.3303		0.9661			15
# 			42.5452		0.6064			20
# 			37.7489		1.2470			25
# 			33.0995		0.7163			30
# 			28.9423		1.1528			35
# 			25.1923		1.1716			40
# 			23.1391		0.5754			45
# 			22.0079		0.7161			50
#
# Média			37.5751		0.8139

# %% [markdown]
# Analisando os resultados acima, vemos que o algoritmo KNN tem a maior acurácia média para nenhum ruído dentro do dataset, mas também é o que mais sofre perda de acurácia conforme o tamanho do ruído. Para o maior ruído, o classificador Bayesiano teve uma melhor acurácia entre os outros algoritmos, apesar de estar muito próxima da acurácia do Naive Bayes. O Naive Bayes teve a média dos desvios padrões para todas as porcentagens de ruído menor que a dos outros classificadores, enquanto o classificador bayesiano teve a maior.
#
# Para ruídos menores, o mais adequado seria utilizar o KNN para classificação dos dados. Para ruídos maiores, no entanto, analisando os dados acima, vemos que o Naive Bayes possui um desempenho melhor que o Classificador Bayesiano, com médias pontuais maiores, sendo o mais adequado para utilizar na classificação dos dados nessa situação. Em certas situações de ruído, o classificador Bayesiano possui acurácia maior que o Naive Bayes, mas são menos ocorrências que o contrário.

# %% [markdown]
# ## 8 – No caso do classificador Naive Bayes, é possível considerar diferentes funções para estimar as probabilidades. Compare os casos: (i) Gaussian Naive Bayes, (ii) multinomial Naive Bayese (iii)Bernoulli Naive Bayes. Considere os casos com e sem normalização.

# %%
from sklearn.naive_bayes import MultinomialNB
def acuraciaMultinomialNaiveBayesValor(features, tipo=0, p=0.7): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    
    X = np.array(features, dtype=float)
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização" 
    
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    mnb = MultinomialNB()
    mnb.fit(train_x, train_y)
    pred_y = mnb.predict(test_x)
    score_MNB = accuracy_score(pred_y, test_y)
    return score

# %%
from sklearn.naive_bayes import BernoulliNB
def acuraciaBernoulliNaiveBayesValor(features, tipo=0, p=0.7): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    
    X = np.array(features, dtype=float)
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização" 
    
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    bnb = BernoulliNB()
    bnb.fit(train_x, train_y)
    pred_y = bnb.predict(test_x)
    score_BNB = accuracy_score(pred_y, test_y)
    return score

# %%
def acuraciaMultinomialNaiveBayesValor(features, tipo=0, p=0.7): #tipo: 0 sem processamento, 1 com padronização, 2 com normalização
    legend = "sem processamento"
    
    X = np.array(features, dtype=float)
    if tipo == 1:
        scaler = StandardScaler().fit(X)
        X = scaler.transform(X)
        legend = "com padronização"
    
    if tipo == 2:
        scaler = MinMaxScaler(feature_range=(0,1))
        scaler.fit(X)
        X = scaler.transform(X)
        legend = "com normalização" 
    
    train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=1-p, random_state=42)
    mnb = MultinomialNB()
    mnb.fit(train_x, train_y)
    pred_y = mnb.predict(test_x)
    score_MNB = accuracy_score(pred_y, test_y)
    return score

# %%
print("Acurácias para o Naive Bayes sem processamento:\n")
print("\tGaussian Naive Bayes: \t\t%.4f" % acuraciaNaiveBayesValor(features, tipo=0, p=0.7))
print("\tMultinomial Naive Bayes:\t%.4f" % acuraciaMultinomialNaiveBayesValor(features, tipo=0, p=0.7))
print("\tBernoulli Naive Bayes: \t\t%.4f"% acuraciaBernoulliNaiveBayesValor(features, tipo=0, p=0.7))

acur_aux = [acuraciaNaiveBayesValor(features, tipo=0, p=0.7), acuraciaMultinomialNaiveBayesValor(features, tipo=0, p=0.7), acuraciaBernoulliNaiveBayesValor(features, tipo=0, p=0.7)]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['GaussianNB', 'MultinomialNB', 'BernoulliNB']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para o Naive Bayes sem processamento')
plt.show(True)
# Out:
# Acurácias para o Naive Bayes sem processamento:
#
# 	Gaussian Naive Bayes: 		0.5413
# 	Multinomial Naive Bayes:	0.6867
# 	Bernoulli Naive Bayes: 		0.6867

# %%
print("Acurácias para o Naive Bayes com normalização:\n")
print("\tGaussian Naive Bayes: \t\t%.4f" % acuraciaNaiveBayesValor(features, tipo=2, p=0.7))
print("\tMultinomial Naive Bayes: \t%.4f" % acuraciaMultinomialNaiveBayesValor(features, tipo=2, p=0.7))
print("\tBernoulli Naive Bayes: \t\t%.4f"% acuraciaBernoulliNaiveBayesValor(features, tipo=2, p=0.7))

acur_aux = [acuraciaNaiveBayesValor(features, tipo=2, p=0.7), acuraciaMultinomialNaiveBayesValor(features, tipo=2, p=0.7), acuraciaBernoulliNaiveBayesValor(features, tipo=2, p=0.7)]
numbers = np.arange(0, len(acur_aux))
plt.bar(numbers, acur_aux, alpha=.45, color=['red', 'green', 'blue'])
classificadores = ['GaussianNB', 'MultinomialNB', 'BernoulliNB']
plt.xticks(numbers, classificadores)
plt.title('Acurácias para o Naive Bayes com normalização')
plt.show(True)
# Out:
# Acurácias para o Naive Bayes com normalização:
#
# 	Gaussian Naive Bayes: 		0.5413
# 	Multinomial Naive Bayes: 	0.6867
# 	Bernoulli Naive Bayes: 		0.6867

# %% [markdown]
# ## 9 –No caso do Knn, compare as classificações usando diferentes métricas. Varie k e mostre as curvas (em um mesmo plot) para as distâncias euclidiana, Manhattan, Chebyshev e Minkowski (p=1.5, p = 3).

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.xlabel("k")
plt.ylabel("Acurácia")

dists = ['euclidean', 'manhattan', 'chebyshev']
for m in dists:
    acur = []
    k_list = []
    for k in range(1, 15):
        acur.append(acuraciaKnnValor(features, tipo=0, p=0.7, metric=m, k=k))
        k_list.append(k)
    plt.plot(k_list, acur, label=m, linewidth=2.5)

p_list = [1.5, 3]
for p_valor in p_list:
    acur = []
    k_list = []
    for k in range(1, 15):
        acur.append(acuraciaKnnValor(features, tipo=0, p=0.7, metric='minkowski', k=k, dist=p_valor))
        k_list.append(k)
    plt.plot(k_list, acur, label='minkowski_'+str(p_valor), linewidth=2.5)    
    

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Analisando o gráfico acima, vemos que utilizar a distância de Manhattan tem como resultado uma maior acurácia na classificação, enquanto utilizar a distância de chebyshev traz uma menor acurácia dentre todas.

# %% [markdown]
# ## 10	– Faça	um	gráfico	da	fração	de	elementos	no	conjunto	de	treinamento	(10%	até	90%	em	passos	de	10%)	versus	acurácia	para	os	classificadores:
# - ### knn	(melhor	k	observado	anteriormente)
# - ### Naive	Bayes
# - ### Decisão	Bayesiana
# ## Considere os	casos com e sem padronização.

# %% [markdown]
# ### k-vizinhos

# %%
acuracia_sem = []
acuracia_com = []
list_p = []
for i in range(1, 10):
    list_p.append(i/10)
    acuracia_sem.append(acuraciaKnnValor(features, tipo=0, p=i/10, k=1))
    acuracia_com.append(acuraciaKnnValor(features, tipo=1, p=i/10, k=1))

print("Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:")
plt.figure(figsize=(15,10))
plt.xlabel("Fração de elementos no conjunto de treinamento")
plt.ylabel("Acurácia")
plt.plot(list_p, acuracia_sem, label = 'sem padronização', linewidth=2.5)
plt.plot(list_p, acuracia_com, label = 'com padronização', linewidth=2.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)
# Out:
# Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:

# %% [markdown]
# Aqui, a padronização aumentou a acurácia do algoritmo.

# %% [markdown]
# ### Classificador bayesiano

# %%
acuracia_sem = []
acuracia_com = []
list_p = []
#não funciona com 10% pois a matriz não é singular e dá erro com o método pdf
for i in range(2, 10):
    list_p.append(i/10)
    acuracia_sem.append(acuraciaBayesValor(features=features, tipo=0, p=i/10))
    acuracia_com.append(acuraciaBayesValor(features=features, tipo=1, p=i/10))
    
print("Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:")
plt.figure(figsize=(15,10))
plt.xlabel("Fração de elementos no conjunto de treinamento")
plt.ylabel("Acurácia")
plt.plot(list_p, acuracia_sem, label = 'sem padronização', linewidth=2.5)
plt.plot(list_p, acuracia_com, label = 'com padronização', linewidth=2.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)
# Out:
# Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:

# %% [markdown]
# Aqui, a padronização não modificou a acurácia inicial do classficador.

# %% [markdown]
# ### Naive Bayes

# %%
acuracia_sem = []
acuracia_com = []
list_p = []
for i in range(1, 10):
    list_p.append(i/10)
    acuracia_sem.append(acuraciaNaiveBayesValor(features=features, tipo=0, p=i/10))
    acuracia_com.append(acuraciaNaiveBayesValor(features=features, tipo=1, p=i/10))
    
print("Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:")
plt.figure(figsize=(15,10))
plt.xlabel("Fração de elementos no conjunto de treinamento")
plt.ylabel("Acurácia")
plt.plot(list_p, acuracia_sem, label = 'sem padronização', linewidth=2.5)
plt.plot(list_p, acuracia_com, label = 'com padronização', linewidth=2.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)
# Out:
# Gráfico da acurácia em função da fração de elementos no conjunto de treinamento:

# %% [markdown]
# Aqui, a padronização não modificou, na expressiva maior parte dos dados, a acurácia em relação a situação sem padronização. No entanto, para uma fração de 40% dos dados para o conjunto de treinamento, a padronização teve um leve aumento, quase nulo, de acurácia em relação à situação sem padronização.
